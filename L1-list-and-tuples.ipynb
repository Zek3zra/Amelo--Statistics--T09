# %% [markdown]
# # LIST AND TUPLES <hr style = "border:2.5px solid #e22424ff"> </hr>

# %% [markdown]
# <b>Amelo Jerow A.</b>
# <br>T09 - A</br>

# %% [markdown]
# ## Creating a List

# %%
numbers =  [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type (numbers)
# Out:
# list

# %%
fruits = ['apple', 'banana', 'cherry']
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
mixed_list = [10,"Hello",3.14,True]
mixed_list
# Out:
# [10, 'Hello', 3.14, True]

# %% [markdown]
# # Indexing

# %%
numbers =  [1,2,3,4,5]

# %%
numbers[2]
# Out:
# 3

# %%
numbers[-3]
# Out:
# 3

# %% [markdown]
# # Modifying Elements

# %%
fruits = ['apple', 'banana', 'cherry']

# %%
fruits [0] = "orange"
fruits
# Out:
# ['orange', 'banana', 'cherry']

# %%
fruits [2] = "orange"
fruits
# Out:
# ['orange', 'banana', 'orange']

# %% [markdown]
# # Adding Elements

# %%
fruits = ['apple', 'banana', 'cherry']

# %%
fruits.append("orange")

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
fruits.insert (1, "blueberry")
fruits
# Out:
# ['apple', 'blueberry', 'banana', 'cherry', 'orange']

# %% [markdown]
# # Removing Elements

# %%
fruits = ['apple', 'banana', 'cherry']
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
"banana" in fruits
# Out:
# True

# %%
"orange" in fruits
# Out:
# False

# %%
fruits.remove("apple")
fruits
# Out:
# ['banana', 'cherry']

# %%
fruits.pop(0)
fruits
# Out:
# ['cherry']

# %% [markdown]
# # Sort() and Sorted()

# %%
numbers =  [3,1,2,5,4]
numbers
# Out:
# [3, 1, 2, 5, 4]

# %%
sorted_numbers = sorted(numbers)
sorted_numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers
# Out:
# [3, 1, 2, 5, 4]

# %%
numbers.sort()
numbers
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # Slicing

# %%
numbers = ['4','5','2','1','3','6','7','8']
numbers
# Out:
# ['4', '5', '2', '1', '3', '6', '7', '8']

# %%
sub = numbers[1:5]
sub
# Out:
# ['5', '2', '1', '3']

# %%
numbers[0:7:2]
# Out:
# ['4', '2', '3', '7']

# %% [markdown]
# # Tuples

# %%
my_tuples = ('4','5','2','1','3','6','7','8')
my_tuples
# Out:
# ('4', '5', '2', '1', '3', '6', '7', '8')

# %%
type (my_tuples)
# Out:
# tuple

# %%
len (my_tuples)
# Out:
# 8

# %%
my_tuples[1:3]
# Out:
# ('5', '2')
